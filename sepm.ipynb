# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
df=pd.read_csv("C:\\Users\\bhava\\OneDrive\\Desktop\\e-waste.csv")
df.info()
df.describe()
df.columns
df.rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   rating out of 5          7385 non-null   float64
#  1   Washingmachine           7385 non-null   float64
#  2   televison                7385 non-null   float64
#  3   laptops                  7385 non-null   float64
#  4   mobile phone             7385 non-null   int64
#  5   total E-waste generated  7385 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 346.3 KB
# Index(['rating out of 5', 'Washingmachine', 'televison', 'laptops',
#        'mobile phone', 'total E-waste generated'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.pairplot(df)
